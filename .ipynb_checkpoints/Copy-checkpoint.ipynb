# %%
##### Python Variable 
#input variable
x= str(input('Enter a numeric value for variable x: '))
print(x)

# b) checking the data type using type function
print(type(x))

# c) ALso convert the data type to integer and assign to variable y
y=int('5')
print(type(y))
# d) converitng the data to float and assign to var z
z=float('40')
print(type(z))
# e) display the type of x,y,z
print(type(x),type(y),type(z))
# Out:
# Enter a numeric value for variable x: 5
# 5
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'> <class 'int'> <class 'float'>

# %%
#### Strings in Python
 # a) Write a Python program to calculate the length of a string.
name= 'Gulsaba'
# print(len(name))

# b)Write a Python program to count the number of characters in a string.
# print(name.count('a'))

# c) Write a Python program to remove the kth index character from a string.
# print(name[:4] + name[4 + 1:])

# d) Write a Python program to remove the characters which have odd index values of a given
# string.
def odd_values_string(str):
  result = "" 
  for i in range(len(str)):
    if i % 2 == 0:
      result = result + str[i]
  return result

# print(odd_values_string('pineapple'))
# print(odd_values_string('python'))

# e) Write a Python script that takes input from the user and displays that input back in upper and
# lower cases.

# print(name.upper())
# print(name.lower())

# f) Write a Python program to sort a string
# print(sorted('gulsaba'))
# print(''.join(sorted('name')))

# g) Write a Python program to reverse a string.
# print((''.join(reversed(name))))

# h) Write a Python program to convert a given string into a list.
# print(list(name))
# Out:
# ['G', 'u', 'l', 's', 'a', 'b', 'a']

# %%
#### Python Lists
# a) Write a Python program to sum (or product) all the items in a list
product_price=[10,20,30,40]
total_price=0
for i in product_price:
    total_price+=i
# print(total_price)

# b) Write a Python program to get the largest/smallest number from a list
# print(max(product_price))
# print(min(product_price))

# c) Write a Python program to print the numbers of a specified list after removing even numbers
# from it

list_of_numbers=[1,2,4,5,6,8]
odd_num_list=[]
for i in list_of_numbers:
    if i%2 != 0:
        odd_num_list.append(i)
# print(odd_num_list)

# d) Write a Python program to select the odd number of a list
 # same as c
    
# e) Write a Python program to convert a list of characters into a string
# Creating a list with elements of string data type  
a_list = ["Python", "Convert", "List", "String", "Method"]  
  
# Converting to string  
string = " ".join( a_list ) # this is read as join elements of a_list with a separator (" ")  
  
# Printing the string  
# print (string)  
# print (type(string)) 

# f) Write a Python program to find the index of an item in a specified list
num =[10, 30, 4, -6]
# print(num.index(30))

# g) Write a Python program to add a list to the second list
list1 = [1, 2, 3, 0]
list2 = ['Red', 'Green', 'Black']
final_list = list1 + list2
# print(final_list)

# h) Write a Python program to get unique values from a list and to count unique values inside a
# list. Also get the frequency of the elements in the list.
mylist=['a', 'a', 'b', 'b', 'b']
set_of_code=[ (i,mylist.count(i)) for i in set(mylist) ]
# print(set_of_code)

# i) Write a Python Program to Extract elements with Frequency greater than K
a = [4, 6, 4, 3, 3, 4, 3, 4, 6, 6]
k = 3
out =  [i for i in set(a) if a.count(i) > k]
# print(out)

# j) Write a Python program to reverse All Strings in String List
test_list = ["Fiha", "is", "best"]

 
# using list comprehension
# Reverse All Strings in String List
res = [i[::-1] for i in test_list]
 
# printing result
print ("The reversed string list is : " + str(res))
# Out:
# The reversed string list is : ['ahiF', 'si', 'tseb']

# %%
 # Python Dictionary
  

 # a) Write a Python script to create a dictionary (i) Create a dictionary named fruit with keys:
# (names, color, taste). add Mango and Lemon as the value of key- names, yellow and green as
# the value of color, sweet and sour as the value of taste. (ii) display the dictionary. (iii) add a
# new value, Apple in the names

fruit={
    "name":["Mango", "Lemon"],
    "color":["Yellow", "Green"],
    "taste":["sweet", "sour"]
    
}
# print(fruit)
fruit['name'].append("Apple")
# print(fruit)

# b) Write a Python program to add a key to a dictionary

fruit["amount"]=["1",2]
# print(fruit)

# c) Write a Python program to check whether a given key already exists in a dictionary.
def is_key_present(x):
  if x in fruit:
      print('Key is present in the dictionary')
  else:
      print('Key is not present in the dictionary')
# is_key_present("name")
# is_key_present("age")

# d) Access dictionary key’s element by index.
# print(list(fruit)[0])
# print(list(fruit)[1])
# print(list(fruit)[2])

# e) Write a Python program to iterate over dictionaries using for loops.
for color_key, value in fruit.items():
    pass
#      print(color_key, 'corresponds to ', fruit[color_key])

# f) Write a Python script to print a dictionary where the keys are numbers between 1 and n (both
# included) and the values are square of keys.

d=dict()
for x in range(1,16):
    d[x]=x**2
# print(d)

# g) Create a dictionary by extracting the keys from a given dictionary
sample_dict = {
    "name": "Kelly",
    "age": 25,
    "salary": 8000,
    "city": "New york"}

# Keys to extract
keys = ["name", "salary"]
newDict = {k: sample_dict[k] for k in keys}
# print(newDict)

# h) Write a Python program to Rename key of a dictionary
sample_dict["NAME"]=sample_dict.pop("name")
# print(sample_dict)

# i) Write a program to print only keys of a dictionary
# print(sample_dict.keys())

# j) Write a program to print values of dictionary.
print(sample_dict.values())
# Out:
# dict_values([25, 8000, 'New york', 'Kelly'])
